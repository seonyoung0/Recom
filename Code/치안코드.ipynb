# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv('C:/Users/LG/공모전/Data/NPA2020.csv',encoding='cp949')

# %%
data = pd.DataFrame(data)

# %%
data_215 = data[data['EVT_CL_CD'] == 215]
data_215.isnull()
# Out:
#          RECV_CPLT_DT  RECV_CPLT_TM  NPA_CL  EVT_STAT_CD  EVT_CL_CD  \
# 3221            False         False   False        False      False
# 3408            False         False   False        False      False
# 3589            False         False   False        False      False
# 3623            False         False   False        False      False
# 3637            False         False   False        False      False
# ...               ...           ...     ...          ...        ...
# 1177831         False         False   False        False      False
# 1177845         False         False   False        False      False
# 1177909         False         False   False        False      False
# 1177918         False         False   False        False      False
# 1177944         False         False   False        False      False
#
#          RPTER_SEX  HPPN_OLD_ADDR  HPPN_X  HPPN_Y  SME_EVT_YN
# 3221         False           True   False   False        True
# ...
